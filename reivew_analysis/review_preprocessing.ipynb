# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inlines
import re

from konlpy.tag import *
# from LDA import *

# %%
# from konlpy.tag import Mecab

# m = Mecab()
# # m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입까지 여러개 있어서 좋습니다, 110V, USB랑 하나로 가성비 좋음 내구성도 ㅇㅋㅇㅋ')

# %%
data = pd.read_csv("C:/Users/shopperhouse/Downloads/레깅스_20240808.csv", index_col = 0)
data.head()
# Out:
#   brand_name                         product_name  write_dt_lst  rating_lst  \
# 0       SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240808           5
# 1       SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807           5
# 2       SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807           5
# 3       SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807           4
# 4       SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240806           5
#
#                                     content_lst
# 0                        저렴하고 괜찮네요 운동할 때 잘입고있어요
# 1                                   편안하게 잘 입을게요
# 2   허리 31~3 허벅지는 얄은편인데 잘맞아요 잡아주지는 못해도 편안함으로 갑니다
# 3  그냥 편하게 홈트할때 입으려고 샀어요~162-47인데 스몰사이즈 편하게 잘맞아요
# 4                 네이비색상 예쁘네요. 물놀이할때 반바지속에 입으려고요

# %%
data.drop_duplicates(subset=['content_lst'], inplace=True)
data
# Out:
#      brand_name                         product_name  write_dt_lst  \
# 0          SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240808
# 1          SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807
# 2          SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807
# 3          SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240807
# 4          SABU  여성 4부 5부 짧은 레깅스 바이커 쇼츠 하이웨스트 운동 스포츠      20240806
# ...         ...                                  ...           ...
# 8165      퍼스트클로            썸머 5부 여름레깅스 면스판 코튼쫄바지 905      20240406
# 8166      퍼스트클로            썸머 5부 여름레깅스 면스판 코튼쫄바지 905      20240401
# 8167      퍼스트클로            썸머 5부 여름레깅스 면스판 코튼쫄바지 905      20240204
# 8169      퍼스트클로            썸머 5부 여름레깅스 면스판 코튼쫄바지 905      20231023
# 8171      퍼스트클로            썸머 5부 여름레깅스 면스판 코튼쫄바지 905      20231018
#
#       rating_lst                                        content_lst
# 0              5                             저렴하고 괜찮네요 운동할 때 잘입고있어요
# 1              5                                        편안하게 잘 입을게요
# 2              5        허리 31~3 허벅지는 얄은편인데 잘맞아요 잡아주지는 못해도 편안함으로 갑니다
# 3              4       그냥 편하게 홈트할때 입으려고 샀어요~162-47인데 스몰사이즈 편하게 잘맞아요
# 4              5                      네이비색상 예쁘네요. 물놀이할때 반바지속에 입으려고요
# ...          ...                                                ...
# 8165           5  빠른 배송 감사합니다.. 넉넉하게 입고 싶어서 2XL로 구매했답니다.. 아~~주~~...
# 8166           5                           자주 입어 물빠져서 또 샀어요ㅎㅎ 너무편해용
# 8167           5                                속옷이.편한하고.다음에.또준문할것요
# 8169           5                          잘입고 있습니다 원피스안에 입어도 안불편합니다
# 8171           5  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...
#
# [7459 rows x 5 columns]

# %%
len(data)
# Out:
# 7459

# %%
from hanspell import spell_checker
import xml.etree.ElementTree as ET

# review_lst = review_df_1['spacing_review'].to_list()

spelled_checked_text = []
for lst in reviews_df['content_lst']:
    try:
        result = spell_checker.check(lst)
        spelled_text = result.checked
    except ET.ParseError:
        spelled_text = lst  # 오류 발생 시 원래 텍스트 사용
    except Exception as e:
        spelled_text = lst  # 기타 예외 발생 시 원래 텍스트 사용
        print(f"Error processing text: {lst}\nException: {e}")
    
    spelled_checked_text.append(spelled_text)

reviews_df['spelled_checked_text'] = spelled_checked_text
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_24708\2567261011.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_df['spelled_checked_text'] = spelled_checked_text

# %%
# reviews_df['review_len'] = reviews_df['content_lst'].str.len()

# %%
reviews_df.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/reivew_leggings.csv', encoding='utf-8-sig')

# %%
reviews_df = pd.read_csv('C:/Users/shopperhouse/Code/GEN_Ailee/reivew_pad.csv', index_col=0)

# %%
reviews_df
# Out:
#                                              content_lst  \
# 0      강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                              항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                        배송빠르고 제품도 넘 좋아요
# 3      늘 쓰던 패드에요. 개딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3번...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480             항상 쓰고 있는 요요쉬 패드 입니다 이번엔 배송이 느려서 좀 아쉽네용
# 51481            배송도빠르고잘포장되어왓읍니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483   댕댕이 키우면서 애기때부터 다른 패드 몇번써봤지만 요요쉬가 짱인것같아요 향기도 좋고 굿
# 51484                    항상쓰는거라 두께도 두껍고 쉬야냄새도 잡이줘서 좋아요^^
# 51485                   항상 애용하는 제품입니다 흡수력도 좋고 빠른배송 감사합니다
#
#                                     spelled_checked_text
# 0      강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...
# 1                           항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!
# 2                                      배송 빠르고 제품도 너무 좋아요
# 3      늘 쓰던 패드에요. 게 딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480              항상 쓰고 있는 요요쉬 패드입니다 이번엔 배송이 느려서 좀 아쉽네요
# 51481        배송도 빠르고 잘 포장되어 왔습니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483  댕댕이 키우면서 아기 때부터 다른 패드 몇 번 써봤지만 요요 시가 최고인 것 같아요...
# 51484                항상 쓰는 거라 두께도 두껍고 쉬야 냄새도 잡이 줘서 좋아요^^
# 51485                  항상 애용하는 제품입니다 흡수력도 좋고 빠른 배송 감사합니다
#
# [46274 rows x 2 columns]

# %%
# reviews_df = pd.read_csv("C:/Users/shopperhouse/Code/GEN_Ailee/reivew_len.csv", index_col = 0)
# reviews_df

# %% [markdown]
# #### delete simple reviews
# 1차 단순 리뷰 제거

# %%
# import numpy as np

# print("최소 : ", np.min(reviews_df['content'].str.len()))
# print("평균 : ", np.average(reviews_df['content'].str.len()))
# print("중앙값 : ", np.median(reviews_df['content'].str.len()))
# print("최댓값 : ", np.max(reviews_df['content'].str.len()))

# # print("최소 : ", np.min(reviews_df['spelled_checked_text'].str.len()))
# # print("평균 : ", np.average(reviews_df['spelled_checked_text'].str.len()))
# # print("중앙값 : ", np.median(reviews_df['spelled_checked_text'].str.len()))
# # print("최댓값 : ", np.max(reviews_df['spelled_checked_text'].str.len()))

# %%
# pip install git+https://github.com/haven-jeon/PyKoSpacing.git

# %% [markdown]
# 0. 텍스트 길이 확인

# %%
print(len((reviews_df[reviews_df['content_lst'].str.len() <= 12])))
reviews_upper_12 = reviews_df[reviews_df['content_lst'].str.len() <= 12]
# Out:
# 6475

# %%
# 텍스트 길이가 12 미만인거 제거
review_df_1 = reviews_df.loc[reviews_df['content_lst'].str.len() > 12]
len(review_df_1)
# Out:
# 39799

# %%
review_df_1
# Out:
#                                              content_lst  \
# 0      강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                              항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                        배송빠르고 제품도 넘 좋아요
# 3      늘 쓰던 패드에요. 개딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3번...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480             항상 쓰고 있는 요요쉬 패드 입니다 이번엔 배송이 느려서 좀 아쉽네용
# 51481            배송도빠르고잘포장되어왓읍니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483   댕댕이 키우면서 애기때부터 다른 패드 몇번써봤지만 요요쉬가 짱인것같아요 향기도 좋고 굿
# 51484                    항상쓰는거라 두께도 두껍고 쉬야냄새도 잡이줘서 좋아요^^
# 51485                   항상 애용하는 제품입니다 흡수력도 좋고 빠른배송 감사합니다
#
#                                     spelled_checked_text
# 0      강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...
# 1                           항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!
# 2                                      배송 빠르고 제품도 너무 좋아요
# 3      늘 쓰던 패드에요. 게 딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480              항상 쓰고 있는 요요쉬 패드입니다 이번엔 배송이 느려서 좀 아쉽네요
# 51481        배송도 빠르고 잘 포장되어 왔습니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483  댕댕이 키우면서 아기 때부터 다른 패드 몇 번 써봤지만 요요 시가 최고인 것 같아요...
# 51484                항상 쓰는 거라 두께도 두껍고 쉬야 냄새도 잡이 줘서 좋아요^^
# 51485                  항상 애용하는 제품입니다 흡수력도 좋고 빠른 배송 감사합니다
#
# [39799 rows x 2 columns]

# %% [markdown]
# 1. 같은 단어가 반복되는 review를 삭제
#
# - 단순 리뷰에 해당하는 단어들 (e.g. 좋아요좋아요좋아요좋아요)
#
# * 해당 부분을 수행하기 전에, 맞춤법 처리 안된 text도 수동으로 몇 개 고쳐줌
# * 사용자 사전 정의 해야하는 단어는 여러가지로 쓰인 경우 하나로 고쳐줌

# %%
# def upper_text(text):
#     text = text.upper()
#     return text

def upper_text(text):
    if pd.notnull(text):  # 텍스트가 Null이 아닌 경우에만 변환
        return text.upper()
    return text  # Null 값은 그대로 반환

# %%
review_df_1['spelled_checked_text'] = review_df_1['spelled_checked_text'].apply(upper_text)
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_21208\1303272380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_1['spelled_checked_text'] = review_df_1['spelled_checked_text'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('ㅜ','')
  text = text.replace('중입니다)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('있었어요','있어요')
  text = text.replace('욥','요')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','')
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('좋ㅡㅂ니다', '좋습니다')
  text = text.replace('졸아요','좋아요')
  text = text.replace('USC','USB')
  text = text.replace('A S','AS')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  
  # text = text.replace('USB', '유에스비')
  text = text.replace('필수 템', '필수템')
  text = text.replace('멀티 어댑터', '멀티어댑터')
  text = text.replace('EU 타입', 'EU타입')
  text = text.replace('느리편', '느린편')
  text = text.replace('요거', '이거')
  text = text.replace('여러 개', '여러개') 
  text = text.replace('내구 성', '내구성')
  text = text.replace('걱정 없이', '걱정없이')
  text = text.replace('부담 없는', '부담없는')
  text = text.replace('내구 성', '내구성')
  text = text.replace('선망', '선만')
  text = text.replace('필요 없음', '필요없음')
  text = text.replace('여향', '여행')
  text = text.replace('있렁서', '있어서')
  text = text.replace('필요 없음', '필요없음')
  text = text.replace('봏아요', '좋아요')
  text = text.replace('죠아용', '좋아요')
  text = text.replace('필요 없음', '필요없음')
  text = text.replace('좋았늡', '좋았습')
  text = text.replace('개벼운', '가벼운')
  text = text.replace('티스트', '테스트')

  text = text.replace('보관 백', '보관백')
  text = text.replace('TYPE', '타입')
  text = text.replace('C TO C', 'C타입')
  text = text.replace('CTOC', 'C타입')
  text = text.replace('C2C', 'C타입')
  text = text.replace('USB-C', 'USB포트 C타입')
  text = text.replace('USB-A', 'USB포트 A타입')
  text = text.replace('C TYPE', 'C타입')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('씨 타입', 'C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('에이 타입', 'A타입')
  text = text.replace('EU 타입', 'EU타입')
  text = text.replace('PD 충전','PD충전')
  text = text.replace('PD 잭', 'PD잭')
  text = text.replace('급 속','급속')
  text = text.replace('포드','포트')
  text = text.replace('포드만','포트')
  text = text.replace('포드리','포트')
  text = text.replace('핸폰','핸드폰')
  text = text.replace('휴대폰', '핸드폰')
  text = text.replace('휴대전화', '핸드폰')
  text = text.replace('11볼트', '110V')
  text = text.replace('22볼트', '220V')
  text = text.replace('11V', '110V')
  text = text.replace('22V', '220V')
  # text = text.replace('35W', '35와트')
  # text = text.replace('45W', '45와트')
  # text = text.replace('65W', '65와트')
  text = text.replace('포터', '포트')
  # text = text.replace('USB', 'USB포트') 
  text = text.replace('USB 포트', 'USB포트')
  text = text.replace('동시 충전', '동시충전')
  text = text.replace('고속 충전', '고속충전')
  text = text.replace('동시 이용', '동시이용')
  text = text.replace('동시 사용', '동시사용')
  text = text.replace('여러 나라', '여러나라')
  text = text.replace('코넥터', '커넥터')
  # 1개짜리는 제외

  text = text.replace('강쥐', '강아지')
  text = text.replace('갱을 쥐', '강아지')
  text = text.replace('쉬', '소변')
  text = text.replace('쉬야', '소변')
  text = text.replace('오줌', '소변')
  text = text.replace('N 번', 'N번')
  text = text.replace('N 년', 'N년')
  text = text.replace('페드','패드')
  text = text.replace('스마트 스토어', '스마트스토어')
  text = text.replace('구매가입니다','구매 각입니다')
  text = text.replace('강쥐','강아지')
  text = text.replace('웨리코기','웰시코기')
  text = text.replace('정 사이즈','정사이즈')
  text = text.replace('습수 력','흡수력')
  text = text.replace('가겍대비','가격 대비')
  text = text.replace('구먀','구매')
  text = text.replace('재재 재주 뭉','재주문')
  text = text.replace('핫 디','할인')
  text = text.replace('여기 거만','여기 것만')
  text = text.replace('제 제제 그메','재구매')
  text = text.replace('저령 렴해서','저렴해서')
  text = text.replace('배변 훈련','배변훈련')
  text = text.replace('요건','이것')
  text = text.replace('몰티즈','말티즈')
  text = text.replace('쟁여두고 습니다','쟁여두고 씁니다')
  text = text.replace('흡수 잔','흡수 잘')
  text = text.replace('만족함 니아','만족합니다')
  text = text.replace('그램',' G')
  text = text.replace('배 편견','배변견')
  text = text.replace('노령견','노견')
  text = text.replace('킬로','KG')
  text = text.replace('개님','개가')
  text = text.replace('편핮니당','편합니다')
  text = text.replace('킬로','KG')
  text = text.replace('ㅏ용','사용')
  text = text.replace('대형 패드','대형패드')
  text = text.replace('배편 판','배변판')
  text = text.replace('R가 성비짱입니다','가성비 짱입니다')
  text = text.replace('파견 가정','파견가정')
  text = text.replace('위생저이에여','위생적이예요')
  text = text.replace('그램','G')
  text = text.replace('가나다라마바사아자차카타파하','')
  text = text.replace('가실 비','가성비')
  text = text.replace('댕댕이','강아지')
  text = text.replace('망상 이 패들만 써요','항상 이 패드만 써요')
  text = text.replace('같은야ㅂ은50','같은 양')
  text = text.replace('쉬야','쉬')
  text = text.replace('유기견 보호소','유기견보호소')
  text = text.replace('갱에 지','강아지')
  text = text.replace('잘약형여 기껏만 습니다','절약형 여기 것만 씁니다 ')
  text = text.replace('매 번지ㅢ구매하는','매번 재구매하는')
  text = text.replace('거성비','가성비')
  text = text.replace('가성 배짱입니다','가성비 짱입니다')
  text = text.replace('싸능데','싸는데')
  text = text.replace('또 주 무 할게요','또 주문할게요')
  text = text.replace('재구 매각','재구매 각')
  text = text.replace('가성 비각','가성비 각')
  text = text.replace('VERY GOOD PRODUCT','아주 좋은 제품')
  text = text.replace('피숑','비숑')
  text = text.replace('논 슬립','논슬립')
  text = text.replace('계소','계속')
  text = text.replace('떨어 지명','떨어지면')
  text = text.replace('대대 만족','대만족')
  text = text.replace('재ㅣ매','재구매')
  text = text.replace('국구닫ㄱ다다다가구구숫ㄱ국','')
  text = text.replace('강지','강아지')
  text = text.replace('성 비','가성비')
  text = text.replace('더드러가여','더 들어가요')
  text = text.replace('배변 판','배변판')
  text = text.replace('퍼피','강아지')
  text = text.replace('가성이','가성비')
  text = text.replace('20G38G40G','20G 38G 40G')
  text = text.replace('이 패들만','이 패드만')

  text = text.replace('먼지 통제 거할 때','먼지통 제거 할 때')
  text = text.replace('흡입 능력','흡입능력')
  text = text.replace('시스탬','시스템')
  text = text.replace('선책','선택')
  text = text.replace('사셈','사세요')
  text = text.replace('워터 루핀','워터루핀')
  text = text.replace('상풍','상품')
  text = text.replace('청소 기밀','청소기 밀')
  text = text.replace('청소 기밀기','청소기 밀기')
  text = text.replace('진 작살','진작 살 ')
  text = text.replace('먼지 통안','먼지통 안')
  text = text.replace('먼 지통','먼지통')
  text = text.replace('먼지 통','먼지통')
  text = text.replace('해르','헤드')
  text = text.replace('가법고','가볍고')
  text = text.replace('삼실','사무실')
  text = text.replace('화이트로','화이트')
  text = text.replace('마니','많이')
  text = text.replace('기욤','귀여움')
  text = text.replace('소제','소재')
  text = text.replace('아소변워요','아쉬워요')
  text = text.replace('아소변우나','아쉬우나')
  text = text.replace('보 풀제 거기','보풀제거기')
  text = text.replace('강화 마루','강화마루')
  text = text.replace('청소 기안에','청소기 안에')
  text = text.replace('흠이 버력','흡입력')
  text = text.replace('누름','누르는')
  text = text.replace('청소역','청소력')
  text = text.replace('채상','책상')
  text = text.replace('청소용임','청소용')
  text = text.replace('가 벼 워서','가벼워서')
  text = text.replace('착지만','작지만')
  text = text.replace('강학요','강해요')
  text = text.replace('머리 타락','머리카락')
  text = text.replace('소올찍히','솔직히')
  text = text.replace('가분','기분')
  text = text.replace('착 아도','작아도')
  text = text.replace('늪이','높이')
  text = text.replace('헤어 두레기','헤어드라이기')
  text = text.replace('앙고','않고')
  text = text.replace('자사소형핸ㄷㄱ청소기','자사 소형 핸드청소기')
  text = text.replace('흡립','흡입')
  text = text.replace('구래도','그래도')
  text = text.replace('정소','청소')
  text = text.replace('최인','최신')
  text = text.replace('작은걸찾았늣데','작은 걸 찾았는데')
  text = text.replace('조그 마한','조그마한')
  text = text.replace('과대광 고언 것 같아요','과대광고 인 것 같아요')
  text = text.replace('반려 묘도','반려묘도')
  text = text.replace('탁입니다','딱입니다')
  text = text.replace('필라 센터','필라테스 센터')
  text = text.replace('주목적','목적')
  text = text.replace('총후 기','청소기')
  text = text.replace('좋진요','좋아요')
  text = text.replace('한보 따립니다','한보따리 입니다')
  text = text.replace('공력','진공력')
  text = text.replace('탈 거 착임','탈거착이')
  text = text.replace('문특','문틀')
  text = text.replace('어주','아주')
  text = text.replace('스투디오','스튜디오')
  text = text.replace('색원','색감')
  text = text.replace('행보해요','행복해요')
  text = text.replace('뒤 덮인','뒤덮인')
  text = text.replace('뎔심','결심')
  text = text.replace('순각','순간')
  text = text.replace('공홈','공식 홈페이지')
  text = text.replace('배턴','배터리')
  text = text.replace('ㅊ','후 차')
  text = text.replace('대파 이프','대 파이프')
  text = text.replace('위봉','위 봉')
  text = text.replace('신준','사준')
  text = text.replace('구서 무석','구석구석')
  text = text.replace('활둉도면','활용도 면')
  text = text.replace('삼성청노기','삼성 청소기')
  text = text.replace('역조','욕조')
  text = text.replace('완저','완전')
  text = text.replace('망어','망이')
  text = text.replace('오자마다','오자마자')
  text = text.replace('안족스럽다네요','만족스럽다네요')
  text = text.replace('장봉익','장봉이')
  text = text.replace('아전','아주')
  text = text.replace('상각','생각')
  text = text.replace('선무','선물')
  text = text.replace('만지','먼지')
  text = text.replace('원하셩거든요','원하셨거든요')
  text = text.replace('싼 마이지만','싼마이지만')
  text = text.replace('긴가 민가','긴가민가')
  text = text.replace('알지게','알차게')
  text = text.replace('흡입려콰','흡입력과 ')
  text = text.replace('자몽할 듯','사용할 듯')
  text = text.replace('정마','정말')
  text = text.replace('가성비 절고','가성비 좋고')
  text = text.replace('뽀송','보송')
  text = text.replace('아음','마음')
  text = text.replace('엄니','어머니')
  text = text.replace('기대 이싱','기대 이상')
  text = text.replace('난립','날림')
  text = text.replace('먼지 날림','먼지날림')
  text = text.replace('파어','파워')
  text = text.replace('소응','소음')
  text = text.replace('가법고','가볍고')
  text = text.replace('너무 귀영 와요','너무 귀여워요')
  text = text.replace('아무래고','아무래도')
  text = text.replace('추전','추천')
  text = text.replace('오시프텔','오피스텔')
  text = text.replace('청소 용구','청소용품')
  text = text.replace('핵 좋음','정말 좋음')
  text = text.replace('엘사','LG')
  text = text.replace('봏았습니다','좋았습니다')
  text = text.replace('청소가 소변워요','청소가 쉬웠어요')
  text = text.replace('총 소포','청사포')
  text = text.replace('탑 오브 탑','탑오브탑')
  text = text.replace('마논','만원')
  text = text.replace('천소','청소')
  text = text.replace('훵씬','훨씬')
  text = text.replace('소변워요','쉬웠어요')
  text = text.replace('스턴딩','스탠딩')
  text = text.replace('그으긋','굿')
  text = text.replace('흡인력','흡입력')

  return text

# %%
review_df_1['spelled_checked_text'] = review_df_1['spelled_checked_text'].apply(replace_text)
review_df_1.head(3)
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_21208\3994088940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_1['spelled_checked_text'] = review_df_1['spelled_checked_text'].apply(replace_text)
#                                          content_lst  \
# 0  강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                          항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                    배송빠르고 제품도 넘 좋아요
#
#                                 spelled_checked_text
# 0  강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...
# 1                       항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!
# 2                                  배송 빠르고 제품도 너무 좋아요

# %%
# #### 앞에서 반복되는 것 제거

# def text_again(text):
#   "공백 기준 반복되는 단어가 있을 경우 반복으로 표시"
#   words = text.split()
#   result = (len(words)==len(set(words)))
#   if result:
#     return 0
#   else:
#     return 1

# %%
# #### 공백 기준 반복 단어만 활용하는 것이 아니라, 연달아 반복이 있는 case 추출 방법

# def text_again_continue(text):
#   words = text.split()

#   # 중복 단어 케이스 (True: 중복 없음)
#   result1 = (len(words)==len(set(words)))

#   # 연속 단어 케이스
#   result2 = 0
#   for i in range(1, len(words)):
#     if words[i] == words[i-1]:
#       result2 = 1
#     else:
#       result2 = 0

#   # 두 케이스가 모두 만족하는 경우 1 반환, 아니면 0 반환 (중복 & 연속)
#   if (str(result1)=='False') & (result2==1):
#     return 1
#   else:
#     return 0

# %%
#### 위 함수 강화 버전 (고유 단어 개수 기반 추가 필터링)

def text_again_dev(text):
  words = text.split()

  # 중복 단어 케이스 (True: 중복 없음)
  result1 = (len(words)==len(set(words)))

  # 연속 단어 케이스
  result2 = 0
  for i in range(1, len(words)):
    if words[i] == words[i-1]:
      result2 = 1
    else:
      result2 = 0

  # 두 케이스가 모두 만족하는 경우 1 반환, 아니면 0 반환 (중복 & 연속)
  result3 = 0
  if (str(result1)=='False') & (result2==1):
    result3 = 1
  else:
    result3 = 0

  #### 세번째 케이스 (set 개수)
  set_len = len(set(words))
  if (result3 == 1) & (set_len <= 3):
    return 1
  else :
    return 0

# %%
# review_df_1['repeated_text'] = review_df_1['spelled_checked_text'].apply(text_again_continue)
# review_df_1.head(3)

# %%
review_df_1['repeated_final'] = review_df_1['spelled_checked_text'].apply(text_again_dev)
review_df_1.head(3)
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_21208\177658694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df_1['repeated_final'] = review_df_1['spelled_checked_text'].apply(text_again_dev)
#                                          content_lst  \
# 0  강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                          항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                    배송빠르고 제품도 넘 좋아요
#
#                                 spelled_checked_text  repeated_final
# 0  강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...               0
# 1                       항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!               0
# 2                                  배송 빠르고 제품도 너무 좋아요               0

# %%
# repeat_df_filtering = review_df_1[review_df_1['repeated_text']==1]/
repeat_filtered = review_df_1[review_df_1['repeated_final']==1]
non_repeat_filtered = review_df_1[review_df_1['repeated_final']!=1]

# %%
len(repeat_filtered)
# Out:
# 150

# %%
non_repeat_filtered
# Out:
#                                              content_lst  \
# 0      강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                              항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                        배송빠르고 제품도 넘 좋아요
# 3      늘 쓰던 패드에요. 개딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3번...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480             항상 쓰고 있는 요요쉬 패드 입니다 이번엔 배송이 느려서 좀 아쉽네용
# 51481            배송도빠르고잘포장되어왓읍니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483   댕댕이 키우면서 애기때부터 다른 패드 몇번써봤지만 요요쉬가 짱인것같아요 향기도 좋고 굿
# 51484                    항상쓰는거라 두께도 두껍고 쉬야냄새도 잡이줘서 좋아요^^
# 51485                   항상 애용하는 제품입니다 흡수력도 좋고 빠른배송 감사합니다
#
#                                     spelled_checked_text  repeated_final
# 0      강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...               0
# 1                           항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!               0
# 2                                      배송 빠르고 제품도 너무 좋아요               0
# 3      늘 쓰던 패드에요. 게 딸이 편하게 소변야하라고 큰 사이즈로 구매합니다.  2-3번...               0
# 4                                         일단 사이즈가 커서 좋아요               0
# ...                                                  ...             ...
# 51480             항상 쓰고 있는 요요소변 패드입니다 이번엔 배송이 느려서 좀 아쉽네요               0
# 51481        배송도 빠르고 잘 포장되어 왔습니다 우리강아지가향이줗아줄겁게사용합니다고맙읍니다               0
# 51483  강아지 키우면서 아기 때부터 다른 패드 몇 번 써봤지만 요요 시가 최고인 것 같아요...               0
# 51484               항상 쓰는 거라 두께도 두껍고 소변야 냄새도 잡이 줘서 좋아요^^               0
# 51485                  항상 애용하는 제품입니다 흡수력도 좋고 빠른 배송 감사합니다               0
#
# [39649 rows x 3 columns]

# %%
keywords = ['잘 사용했습니다', '잘 이용했습니다', '잘 사용했어요','잘 썼습니다', '잘 썼어요', '잘 쓰고왔어요', '잘 받았습니다', '잘 받았어요', '사용하려고요', '잘 사용', '많이 파세요', '아주 좋아요',
            '잘 이용하고 있어요', '잘 이용', '잘 쓰고있습니다', '잘 쓰고 있습니다', '잘 쓰고있어요', '잘 쓰겠슴당', '잘 되네요', '잘 작동돼요','잘 됩니다', '잘 이용하겠습니다', '잘 사용하겠습니다', '잘 쓰겠습니다', '잘 샀어요', '잘 써볼게요', '잘 쓸게요',
            '구매했는데','아직', '여행', '사용 전', '번창','최고예요','좋습니다','강추합니다', '여행 가려고', '여행 가서',  '잘 돼요', '잘 산 것 같아요', '잘 쓰고 있어요', '그냥', '써볼게요', 
            '구매 했어요','구매 했습니다', '너무 좋아요', '좋습니다', '너무 좋습니다', '않았습니다', '않았네요', '빨리','후기','구입','주문','리뷰','수령','협찬','감사합니다','좋았습니다',' 좋네요', ' 좋아요', '면세점', '좋아 보여요', '좋겠네요',
            '수고하세요','만족합니다','사용 후 후기', '좋아하세요','좋겠어요', '안좋아요', '잘됩니다', '귀엽네요', '기대됩니다', '바랍니다', '훌륭합니다', '훌륭하네요', '유용하네요', '유용합니다', '아쉬웠네요',
            '만족스럽습니다', '잘 되네요', '이거 사세요', '강추입니다', '추천', '조만간', '편리', '이용', '잘', '좋은 거', '작동', '신행', '신혼여행', '신혼 여행', '좋은 것', '좋은 거','편리', '좋아하네요', '문제없었어요',
            '좋아 보입니다', '마음', '맘', '좋더라고요', '편했습니다', '최고', '와우', '대만족', '필수', '여행 필수품', '튼튼', '매력',
            '굿', '굳', 'N번', 'N년', '애용', '항상', '늘', '꾸준히', '쭉', '애용', '항상', '늘', '매번', '매일', '몇 년', '조타' ,'조아'] 

# common_entity = ['배송','프로모션', '가격', '가성비', '싼값', '재구매','포장','판매','저렴','할인','촉진','AS', '문의', '답변','상담',
#                  '유럽', '런던', '미국', '괌', '대만', '일본', '영국', '홍콩', '심천', '마카오' ,'뉴질랜드', '호주', '발리', '베트남', '스위스', '스페인','뉴욕','도쿄', '체코', '오스트리아',
#                 '나라','국가','태국','동유럽','이탈리아','파리','타이베이','두바이','코타키나발루','두바이','싱가포르','요르단','말레이시아', '이집트', '서유럽', '동유럽','탄자니아', '동북아시아', '동남아시아', '칠레'] #재구매

# entity = ['멀티','어댑터', '멀티어댑터','고속충전', 'C타입', '젠더', 'V', '220', '110', 'PD', 'W','하나', 'USB', '포트', '충전','USB포트',
#           '색상', '색깔', '색', '디자인', '파우치', '고속', '포트','타입','케이스','고속','콘센트','배터리','케이블','퓨즈','단자','폰','전자기기','태블릿','휴대','무게','사이즈','실용','크기','성능','속도',
#           '퀄리티','컴팩트','모양','수명','안전성','휴대','무게','사이즈','실용','크기','성능','속도','퀄리티','콤팩트','만능',
#           '세련','사용성','수명','안전성','호환','품질','스펙','고출력','LED','돼지코','물건','견고','영구','기능','구성','KC','인증','자동복구']

common_entity = ['배송','프로모션', '가격', '가성비', '싼값', '구매', '재구매','포장','판매','저렴','할인','촉진','AS', '문의', '답변','상담']

entity = ['중량','색상', '색깔', '색', '디자인', '무게','사이즈','크기','성능','속도','퀄리티','모양','수명','안전성','휴대','콤팩트','만능',
          '사용성', '사용감','호환', '품질','스펙','견고','영구','기능','구성', 'KC', '인증']


keywords_patterns = '|'.join(keywords)
common_entity_patterns = '|'.join(common_entity)
entity_patterns = '|'.join(entity)
# nation_patterns = '|'.join(nation)

simple_df = non_repeat_filtered[
    (non_repeat_filtered['spelled_checked_text'].str.contains(keywords_patterns, na=False)) &
    (~non_repeat_filtered['spelled_checked_text'].str.contains(common_entity_patterns, na=False)) &
    # (~non_repeat_filtered['spelled_checked_text'].str.contains(nation_patterns, na=False)) &
    (~non_repeat_filtered['spelled_checked_text'].str.contains(entity_patterns, na=False)) &
    (non_repeat_filtered['spelled_checked_text'].str.len() <= 28)
]


# keyword, text_len 두가지 조건을 포함해서 나오는 리뷰 1,889개
# keyword, entity, text_len 세가지 조건을 포함해서 나오는 리뷰 1,699개
# keyword, entity, nation, text_len 세가지 조건을 포함해서 나오는 리뷰

# %%
simple_df
# Out:
#                         content_lst          spelled_checked_text  \
# 8                     너무 잘쓰고 있습니다~~                너무 잘 쓰고 있습니다~~
# 12          꾸준히 사용중인 제품 잘 사용하고 있습니다      꾸준히 사용 중인 제품 잘 사용하고 있습니다
# 15                 민족합니다 잘 사용하고 있어요             민족 합니다 잘 사용하고 있어요
# 17                    자주사용하는제품..좋아요              자주 사용하는 제품.. 좋아요
# 24                    항상 떨어지지 않게. .                 항상 떨어지지 않게. .
# ...                             ...                           ...
# 51446                흥수잘되고 레몬향이 진해요               흥수 잘되고 레몬향이 진해요
# 51447         레몬향도 향긋하고 흡수도 잘되고 좋아요         레몬향도 향긋하고 흡수도 잘되고 좋아요
# 51451        패드가얇은데 보기보다잘흡수돼요 향도좋아요    패드가 얇은데 보기보다 잘 흡수돼요 향도 좋아요
# 51470              늘 잘 사용하고 있습니다 :)              늘 잘 사용하고 있습니다 :)
# 51475  향도 좋고 흡수력도 괜찮고 이번에도 잘 사용했어요~  향도 좋고 흡수력도 괜찮고 이번에도 잘 사용했어요~
#
#        repeated_final
# 8                   0
# 12                  0
# 15                  0
# 17                  0
# 24                  0
# ...               ...
# 51446               0
# 51447               0
# 51451               0
# 51470               0
# 51475               0
#
# [9413 rows x 3 columns]

# %%
# simple = pd.concat([repeat_filtered, simple_df], axis = 0)
# simple.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/simple_review.csv')

# %%
del_simple_df = non_repeat_filtered[~non_repeat_filtered.index.isin(simple_df.index)]
del_simple_df
# Out:
#                                              content_lst  \
# 0      강아지 2마리와 살다보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기 ...
# 1                              항상 쓰던거예요 가성비좋구 배송도빠르고 짱!!
# 2                                        배송빠르고 제품도 넘 좋아요
# 3      늘 쓰던 패드에요. 개딸이 편하게 쉬야하라고 큰 사이즈로 구매합니다. ㅋㅋ 2-3번...
# 4                                         일단 사이즈가 커서 좋아요
# ...                                                  ...
# 51480             항상 쓰고 있는 요요쉬 패드 입니다 이번엔 배송이 느려서 좀 아쉽네용
# 51481            배송도빠르고잘포장되어왓읍니다 우리댕댕이가향이줗아줄겁게사용합니다고맙읍니다
# 51483   댕댕이 키우면서 애기때부터 다른 패드 몇번써봤지만 요요쉬가 짱인것같아요 향기도 좋고 굿
# 51484                    항상쓰는거라 두께도 두껍고 쉬야냄새도 잡이줘서 좋아요^^
# 51485                   항상 애용하는 제품입니다 흡수력도 좋고 빠른배송 감사합니다
#
#                                     spelled_checked_text  repeated_final
# 0      강아지 2마리와 살다 보니 배변패드가 많이 필요하네요. 배변 흔적은 바로바로 치우기...               0
# 1                           항상 쓰던 거예요 가성비 좋고 배송도 빠르고 짱!!               0
# 2                                      배송 빠르고 제품도 너무 좋아요               0
# 3      늘 쓰던 패드에요. 게 딸이 편하게 소변야하라고 큰 사이즈로 구매합니다.  2-3번...               0
# 4                                         일단 사이즈가 커서 좋아요               0
# ...                                                  ...             ...
# 51480             항상 쓰고 있는 요요소변 패드입니다 이번엔 배송이 느려서 좀 아쉽네요               0
# 51481        배송도 빠르고 잘 포장되어 왔습니다 우리강아지가향이줗아줄겁게사용합니다고맙읍니다               0
# 51483  강아지 키우면서 아기 때부터 다른 패드 몇 번 써봤지만 요요 시가 최고인 것 같아요...               0
# 51484               항상 쓰는 거라 두께도 두껍고 소변야 냄새도 잡이 줘서 좋아요^^               0
# 51485                  항상 애용하는 제품입니다 흡수력도 좋고 빠른 배송 감사합니다               0
#
# [30236 rows x 3 columns]

# %%
# del_simple_df.to_csv("C:/Users/shopperhouse/Code/GEN_Ailee/all_del_simple_review.csv")

# %% [markdown]
# #### sentence tokenize

# %%
import kss
from kss import split_sentences

def kss_sentence_split(text):
    return kss.split_sentences(text)

del_simple_df['kss_split_text'] = del_simple_df['spelled_checked_text'].apply(kss_sentence_split)
# Out:
# [Kss]: Because there's no supported C++ morpheme analyzer, Kss will take pecab as a backend. :D
# For your information, Kss also supports mecab backend.
# We recommend you to install mecab or konlpy.tag.Mecab for faster execution of Kss.
# Please refer to following web sites for details:
# - mecab: https://cleancode-ws.tistory.com/97
# - konlpy.tag.Mecab: https://uwgdqo.tistory.com/363
#
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_21208\4093034592.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del_simple_df['kss_split_text'] = del_simple_df['spelled_checked_text'].apply(kss_sentence_split)

# %%
review_df_2 = del_simple_df.copy()

# %%
def str_to_list(text):
    if isinstance(text, str):
        try:
            return eval(text)
        except:
            return text
    return text

# %%
# 위 함수 적용
review_df_2['spelled_checked_text'] = review_df_2['spelled_checked_text'].apply(str_to_list)
review_df_2['kss_split_text'] = review_df_2['kss_split_text'].apply(str_to_list)

# %%
# 여러 단어 기준으로 문자열 분리하는 함수 정의
def split_by_multiple_words(text, words):
    parts = [text]
    for word in words:
        new_parts = []
        for part in parts:
            new_parts.extend(split_by_word(part, word))
        parts = new_parts
    return parts

# 단어 기준으로 문자열 분리하는 기본 함수 정의
def split_by_word(text, word):
    parts = []
    start = 0
    while True:
        index = text.find(word, start)
        if index == -1:
            break
        parts.append(text[start:index + len(word)])
        start = index + len(word)
    parts.append(text[start:])
    return parts

def handle_non_string(x):
    if isinstance(x, str):
        return x
    else:
        return ""

# 여러 단어 기준으로 분리할 단어 리스트 정의
words_to_split = ['빠르고', '스럽고', ',']

# split_text 열을 분리하여 새로운 열 생성
review_df_3 = review_df_2.explode(['kss_split_text'])
review_df_3['kss_split_text'] = review_df_3['kss_split_text'].apply(handle_non_string)
# review_df_3['all_split_text'] = review_df_3['kss_split_text'].apply(lambda x: split_by_multiple_words(x, words_to_split))
review_df_3['all_split_text'] = review_df_3['kss_split_text'].apply(lambda x: split_by_multiple_words(x, words_to_split))

# %%
review_df_4 = review_df_3.explode(['all_split_text'])
review_df_4
# Out:
#                                             content_lst  \
# 0                                저렴하고 괜찮네요 운동할 때 잘입고있어요
# 0                                저렴하고 괜찮네요 운동할 때 잘입고있어요
# 2           허리 31~3 허벅지는 얄은편인데 잘맞아요 잡아주지는 못해도 편안함으로 갑니다
# 2           허리 31~3 허벅지는 얄은편인데 잘맞아요 잡아주지는 못해도 편안함으로 갑니다
# 3          그냥 편하게 홈트할때 입으려고 샀어요~162-47인데 스몰사이즈 편하게 잘맞아요
# ...                                                 ...
# 8166                           자주 입어 물빠져서 또 샀어요ㅎㅎ 너무편해용
# 8166                           자주 입어 물빠져서 또 샀어요ㅎㅎ 너무편해용
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...
#
#                                    spelled_checked_text  repeated_final  \
# 0                              저렴하고 괜찮네요 운동할 때 잘 입고 있어요               0
# 0                              저렴하고 괜찮네요 운동할 때 잘 입고 있어요               0
# 2         허리 31~3 허벅지는 얄은 편인데 잘 맞아요 잡아주지는 못해도 편안함으로 갑니다               0
# 2         허리 31~3 허벅지는 얄은 편인데 잘 맞아요 잡아주지는 못해도 편안함으로 갑니다               0
# 3      그냥 편하게 홈트 할 때 입으려고 샀어요~162-47인데 스몰 사이즈 편하게 잘 맞아요               0
# ...                                                 ...             ...
# 8166                           자주 입어 물 빠져서 또 샀어요 너무 편해요               0
# 8166                           자주 입어 물 빠져서 또 샀어요 너무 편해요               0
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...               0
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...               0
# 8171  이 제품은 정말 좋아서 재구매했어요. 기모로 도 이 정도 기장 제품 나오면 아이들 ...               0
#
#                                          kss_split_text  \
# 0                                             저렴하고 괜찮네요
# 0                                        운동할 때 잘 입고 있어요
# 2                             허리 31~3 허벅지는 얄은 편인데 잘 맞아요
# 2                                   잡아주지는 못해도 편안함으로 갑니다
# 3                               그냥 편하게 홈트 할 때 입으려고 샀어요~
# ...                                                 ...
# 8166                                  자주 입어 물 빠져서 또 샀어요
# 8166                                             너무 편해요
# 8171                               이 제품은 정말 좋아서 재구매했어요.
# 8171     기모로 도 이 정도 기장 제품 나오면 아이들 교복 안에 입기 정말 좋을 것 같아요.
# 8171  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...
#
#                                          all_split_text
# 0                                             저렴하고 괜찮네요
# 0                                        운동할 때 잘 입고 있어요
# 2                             허리 31~3 허벅지는 얄은 편인데 잘 맞아요
# 2                                   잡아주지는 못해도 편안함으로 갑니다
# 3                               그냥 편하게 홈트 할 때 입으려고 샀어요~
# ...                                                 ...
# 8166                                  자주 입어 물 빠져서 또 샀어요
# 8166                                             너무 편해요
# 8171                               이 제품은 정말 좋아서 재구매했어요.
# 8171     기모로 도 이 정도 기장 제품 나오면 아이들 교복 안에 입기 정말 좋을 것 같아요.
# 8171  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...
#
# [11719 rows x 5 columns]

# %%
review_df_4.rename(columns={'spelled_checked_text' : 'spelled_check_review',
                            'kss_split_text' : 'kss_split_review',
                            'all_split_text' : 'add_rule_based_split_review'}, inplace = True)

# %%
# review_df_4.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/sentok_del_simple_review.csv', encoding = 'utf-8-sig')

# %% [markdown]
# #### seperate service, product reviews

# %%
add_rule_based_split_review = review_df_4[['add_rule_based_split_review']]
add_rule_based_split_review.reset_index(drop = True, inplace=True)

# %%
add_rule_based_split_review
# Out:
#                              add_rule_based_split_review
# 0                                              저렴하고 괜찮네요
# 1                                         운동할 때 잘 입고 있어요
# 2                              허리 31~3 허벅지는 얄은 편인데 잘 맞아요
# 3                                    잡아주지는 못해도 편안함으로 갑니다
# 4                                그냥 편하게 홈트 할 때 입으려고 샀어요~
# ...                                                  ...
# 11714                                  자주 입어 물 빠져서 또 샀어요
# 11715                                             너무 편해요
# 11716                               이 제품은 정말 좋아서 재구매했어요.
# 11717     기모로 도 이 정도 기장 제품 나오면 아이들 교복 안에 입기 정말 좋을 것 같아요.
# 11718  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...
#
# [11719 rows x 1 columns]

# %%
# keywords = ['잘 사용했습니다', '잘 이용했습니다', '잘 사용했어요','잘 썼습니다', '잘 썼어요', '잘 쓰고왔어요', '잘 받았습니다', '잘 받았어요', '사용하려고요', '잘 사용', '많이 파세요', '아주 좋아요',
#             '잘 이용하고 있어요', '잘 이용', '잘 쓰고있습니다', '잘 쓰고 있습니다', '잘 쓰고있어요', '잘 쓰겠슴당', '잘 되네요', '잘 작동돼요','잘 됩니다', '잘 이용하겠습니다', '잘 사용하겠습니다', '잘 쓰겠습니다', '잘 샀어요', '잘 써볼게요', '잘 쓸게요',
#             '구매했는데','아직', '여행', '사용 전', '번창','최고예요','좋습니다','강추합니다', '여행 가려고', '여행 가서',  '잘 돼요', '잘 산 것 같아요', '잘 쓰고 있어요', '그냥', '써볼게요', 
#             '구매 했어요','구매 했습니다', '너무 좋아요', '너무 좋습니다', '않았습니다', '않았네요', '빨리','후기','구입','주문','리뷰','수령','협찬','감사합니다','좋았습니다',' 좋네요', ' 좋아요', '면세점', '좋아 보여요', '좋겠네요',
#             '수고하세요','만족합니다','사용 후 후기', '좋겠어요', '안좋아요', '잘됩니다', '귀엽네요', '기대됩니다', '바랍니다', '훌륭합니다', '훌륭하네요', '유용하네요', '유용합니다', '아쉬웠네요',
#             '만족스럽습니다', '잘 되네요', '이거 사세요', '강추입니다', '추천', '조만간', '편리', '이용', '잘', '좋은 거', '작동', '신행', '신혼여행', '신혼 여행', '좋은 것', '좋은 거','편리', '좋아하네요', '문제없었어요',
#             '좋아 보입니다', '마음', '맘', '좋더라고요', '편했습니다', '최고', '와우', '대만족', '필수', '여행 필수품', '괜찮은 것 같습니다', '사용', '템', '탬', '튼튼'] 
# # 에이 -> A, 씨 -> C

# common_entity = ['배송','프로모션', '가격', '가성비', '싼값', '재구매','포장','판매','저렴','할인','촉진','재송','AS', 
#                  '유럽', '런던', '미국', '괌', '대만', '일본', '영국', '홍콩', '심천', '마카오' ,'뉴질랜드', '호주', '발리', '베트남', '스위스', '스페인','뉴욕','도쿄', '체코', '오스트리아',
#                 '나라','국가','태국','동유럽','이탈리아','파리','타이베이','두바이','코타키나발루','두바이','싱가포르','요르단','말레이시아'] #재구매

# entity = ['멀티','어댑터', '멀티어댑터','고속 충전', 'C 타입', 'c', 'c타입', 'C타입', '에이 타입', '씨타입', '에이타입', '씨타입','젠더', 'v', 'V', '220', '110', 'PD', 'pd', 'w', 'W','하나', 'USB', 'usb', '충전',
#            '색상', '색깔', '색', '디자인', '파우치', '11', '22', 
#           '포트','타입','케이스','고속','콘센트','배터리','케이블','퓨즈','단자','포터','폰','전자기기','태블릿','코넥터','휴대','무게','사이즈','실용','크기','성능','속도',
#           '퀄리티','컴팩트','용이','모양','만능','휴대','무게','사이즈','실용','크기','성능','속도','퀄리티','컴팩트','용이','모양','만능',
#           '세련','수명','안전성','호환','튼튼','품질','스펙','CtoC','고출력','LED','돼지코','물건','견고','보관백','영구','기능','구성','매력','KC','인증','자동복구']

# keywords = ['잘 사용했습니다', '잘 이용했습니다', '잘 사용했어요','잘 썼습니다', '잘 썼어요', '잘 쓰고왔어요', '잘 받았습니다', '잘 받았어요', '사용하려고요', '잘 사용', '많이 파세요', '아주 좋아요',
#             '잘 이용하고 있어요', '잘 이용', '잘 쓰고있습니다', '잘 쓰고 있습니다', '잘 쓰고있어요', '잘 쓰겠슴당', '잘 되네요', '잘 작동돼요','잘 됩니다', '잘 이용하겠습니다', '잘 사용하겠습니다', '잘 쓰겠습니다', '잘 샀어요', '잘 써볼게요', '잘 쓸게요',
#             '구매했는데','아직', '여행', '사용 전', '번창','최고예요','좋습니다','강추합니다', '여행 가려고', '여행 가서',  '잘 돼요', '잘 산 것 같아요', '잘 쓰고 있어요', '그냥', '써볼게요', 
#             '구매 했어요','구매 했습니다', '너무 좋아요', '너무 좋습니다', '않았습니다', '않았네요', '빨리','후기','구입','주문','리뷰','수령','협찬','감사합니다','좋았습니다',' 좋네요', ' 좋아요', '면세점', '좋아 보여요', '좋겠네요',
#             '수고하세요','만족합니다','사용 후 후기', '좋겠어요', '안좋아요', '잘됩니다', '귀엽네요', '기대됩니다', '바랍니다', '훌륭합니다', '훌륭하네요', '유용하네요', '유용합니다', '아쉬웠네요',
#             '만족스럽습니다', '잘 되네요', '이거 사세요', '강추입니다', '추천', '조만간', '편리', '이용', '잘', '좋은 거', '작동', '신행', '신혼여행','해외','신혼 여행', '좋은 것', '좋은 거','편리', '좋아하네요', '문제없었어요',
#             '좋아 보입니다', '마음', '맘', '좋더라고요', '편했습니다', '최고', '와우', '대만족', '필수', '여행 필수품', '튼튼', '매력','필수','탬','템'] 
# # 에이 -> A, 씨 -> C

# common_entity = ['배송','프로모션', '가격', '가성비', '싼값', '재구매','포장','판매','저렴','할인','촉진','AS', '금액', '문의', '답변',
#                  '유럽', '런던', '미국', '괌', '대만', '일본', '영국', '홍콩', '심천', '마카오' ,'뉴질랜드', '호주', '발리', '베트남', '스위스', '스페인','뉴욕','도쿄', '체코', '오스트리아',
#                 '나라','국가','태국','동유럽','이탈리아','파리','타이베이','두바이','코타키나발루','두바이','싱가포르','요르단','말레이시아', '이집트', '서유럽', '동유럽','탄자니아', '동북아시아', '동남아시아', '칠레'] #재구매

# entity = ['멀티','어댑터', '멀티어댑터','고속충전', 'C타입', '젠더', 'V', '220', '110', 'PD', 'W','하나', 'USB', '포트', '충전','USB포트',
#           '색상', '색깔', '색', '디자인', '파우치', '고속', '포트','타입','케이스','고속','콘센트','배터리','케이블','퓨즈','단자','폰','전자기기','태블릿','휴대','무게','사이즈',
#           '퀄리티','컴팩트','모양','수명','안전성','휴대','무게','사이즈','실용','크기','성능','속도','만능',
#           '세련','사용성','수명','호환','품질','스펙','고출력','LED','돼지코','물건','견고','영구','기능','구성','KC','인증','자동복구']

keywords = ['잘 사용했습니다', '잘 이용했습니다', '잘 사용했어요','잘 썼습니다', '잘 썼어요', '잘 쓰고왔어요', '잘 받았습니다', '잘 받았어요', '사용하려고요', '잘 사용', '많이 파세요', '아주 좋아요',
            '잘 이용하고 있어요', '잘 이용', '잘 쓰고있습니다', '잘 쓰고 있습니다', '잘 쓰고있어요', '잘 쓰겠슴당', '잘 되네요', '잘 작동돼요','잘 됩니다', '잘 이용하겠습니다', '잘 사용하겠습니다', '잘 쓰겠습니다', '잘 샀어요', '잘 써볼게요', '잘 쓸게요',
            '구매했는데','아직', '여행', '사용 전', '번창','최고예요','좋습니다','강추합니다', '여행 가려고', '여행 가서',  '잘 돼요', '잘 산 것 같아요', '잘 쓰고 있어요', '그냥', '써볼게요', 
            '구매 했어요','구매 했습니다', '너무 좋아요', '좋습니다', '너무 좋습니다', '않았습니다', '않았네요', '빨리','후기','구입','주문','리뷰','수령','협찬','감사합니다','좋았습니다','좋네요', '좋아요', '좋을 거', '좋을 것', '면세점', '좋아 보여요', '좋겠네요',
            '수고하세요','만족합니다','사용 후 후기', '좋아하세요','좋겠어요', '안좋아요', '잘됩니다', '귀엽네요', '기대됩니다', '바랍니다', '훌륭합니다', '훌륭하네요', '유용하네요', '유용합니다', '아쉬웠네요',
            '만족스럽습니다', '잘 되네요', '이거 사세요', '강추입니다', '추천', '조만간', '편리', '이용', '잘', '좋은 거', '작동', '신행', '신혼여행', '신혼 여행', '좋은 것', '좋은 거','편리', '좋아하네요', '문제없었어요',
            '좋아 보입니다', '마음', '맘', '좋더라고요', '편했습니다', '최고', '와우', '대만족', '필수', '여행 필수품', '튼튼', '매력',
            '굿', '굳', 'N번', 'N년', '애용', '항상', '늘', '꾸준히', '쭉', '애용', '항상', '늘', '매번', '매일', '계속', '몇 년', '조타' ,'조아'] 

common_entity = ['배송','프로모션', '가격', '가성비', '싼값', '구매', '재구매','포장','판매','저렴','할인','촉진','AS', '문의', '답변','상담'] #재구매

entity = ['중량','색상', '색깔', '색', '디자인', '무게','사이즈','크기','성능','속도','퀄리티','모양','수명','안전성','휴대','콤팩트','만능',
          '사용성','호환', '품질','스펙','견고','영구','기능','구성','인증', '소재']   # 소재       

keywords_patterns = '|'.join(keywords)
common_entity_patterns = '|'.join(common_entity)
entity_patterns = '|'.join(entity)

def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

add_rule_based_split_review['add_rule_based_split_review'] = add_rule_based_split_review['add_rule_based_split_review'].apply(clean_text)
add_rule_based_split_review.dropna(axis = 1)

simple_df_2 = add_rule_based_split_review[
    (add_rule_based_split_review['add_rule_based_split_review'].str.contains(keywords_patterns, na = False)) &
    (~add_rule_based_split_review['add_rule_based_split_review'].str.contains(common_entity_patterns, na = False)) &
    (~add_rule_based_split_review['add_rule_based_split_review'].str.contains(entity_patterns, na = False))
    # (add_rule_based_split_review['add_rule_based_split_review'].str.len() <= 3)
]
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_24708\1497550232.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_rule_based_split_review['add_rule_based_split_review'] = add_rule_based_split_review['add_rule_based_split_review'].apply(clean_text)

# %%
# simple_df_2[simple_df_2['add_rule_based_split_review'].str.contains('튼튼')]

# %%
simple_df_2
# Out:
#                          add_rule_based_split_review
# 1                                     운동할 때 잘 입고 있어요
# 2                           허리 313 허벅지는 얄은 편인데 잘 맞아요
# 4                             그냥 편하게 홈트 할 때 입으려고 샀어요
# 8                                         너무 편하고 좋아요
# 12                                                굿굿
# ...                                              ...
# 11697                                   편하고 신축성도 좋아요
# 11704                         완전 여름용으로 흐늘흐늘 얇지는 않습니다
# 11706                                   통통 딸내미 잘 맞아요
# 11712                                        잘 입겠습니다
# 11717  기모로 도 이 정도 기장 제품 나오면 아이들 교복 안에 입기 정말 좋을 것 같아요
#
# [3357 rows x 1 columns]

# %%
simple_df_3 = add_rule_based_split_review[
    (~add_rule_based_split_review['add_rule_based_split_review'].str.contains(common_entity_patterns, na = False)) &
    (~add_rule_based_split_review['add_rule_based_split_review'].str.contains(entity_patterns, na = False)) &
    (add_rule_based_split_review['add_rule_based_split_review'].str.len() <= 7)
]

# %%
simple_df_3
# Out:
#       add_rule_based_split_review
# 12                             굿굿
# 14                         아주 편해요
# 17                        잘 입겠습니다
# 31                         진짜 편해요
# 45                        너무 편합니다
# ...                           ...
# 11710                      아주 편하고
# 11711                       부드럽네요
# 11712                     잘 입겠습니다
# 11713                           0
# 11715                      너무 편해요
#
# [1669 rows x 1 columns]

# %%
del_simple_df_2 = add_rule_based_split_review[~add_rule_based_split_review.index.isin(simple_df_2.index)]
del_simple_df_2 = del_simple_df_2[~del_simple_df_2.index.isin(simple_df_3.index)]
del_simple_df_2
# Out:
#                              add_rule_based_split_review
# 0                                              저렴하고 괜찮네요
# 3                                    잡아주지는 못해도 편안함으로 갑니다
# 5                               16247인데 스몰 사이즈 편하게 잘 맞아요
# 6                                            네이비 색상 예쁘네요
# 7                                    물놀이할 때 반바지 속에 입으려고요
# ...                                                  ...
# 11708                                        빠른 배송 감사합니다
# 11709                            넉넉하게 입고 싶어서 2XL로 구매했답니다
# 11714                                  자주 입어 물 빠져서 또 샀어요
# 11716                                이 제품은 정말 좋아서 재구매했어요
# 11718  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...
#
# [7403 rows x 1 columns]

# %%
# del_simple_df_2.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/all_del_simple_review.csv', encoding='utf-8-sig')

# %%
service_review = del_simple_df_2[
    (del_simple_df_2['add_rule_based_split_review'].str.contains(common_entity_patterns)) &
    (~del_simple_df_2['add_rule_based_split_review'].str.contains(entity_patterns))
    # (add_rule_based_split_review['add_rule_based_split_review'].str.len() <= 7)
]

# %%
service_review
# Out:
#                             add_rule_based_split_review
# 0                                             저렴하고 괜찮네요
# 9                                        가격 대비 완전히 만족해요
# 11     운동할 때 입어 여고 2벌 구매했는데 2벌 정도 더 사서 입ㅇ이어야겠어요 편하고 좋아요
# 15                                           그냥 가격만큼이네요
# 18                                               배송 빠르고
# ...                                                 ...
# 11691                                          계속ㅈ구매 예정
# 11698                                         재구매 3번째예요
# 11708                                       빠른 배송 감사합니다
# 11709                           넉넉하게 입고 싶어서 2XL로 구매했답니다
# 11716                               이 제품은 정말 좋아서 재구매했어요
#
# [1609 rows x 1 columns]

# %%
service_review['review_type'] = 'service'
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_24708\9108574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   service_review['review_type'] = 'service'

# %%
product_review = del_simple_df_2[~del_simple_df_2.index.isin(service_review.index)]
product_review
# Out:
#                              add_rule_based_split_review
# 3                                    잡아주지는 못해도 편안함으로 갑니다
# 5                               16247인데 스몰 사이즈 편하게 잘 맞아요
# 6                                            네이비 색상 예쁘네요
# 7                                    물놀이할 때 반바지 속에 입으려고요
# 10                                        허리 짱짱하고 너무 편해요
# ...                                                  ...
# 11702                               소재도 면이라서 부드럽고 너무 좋아요
# 11703                    사이즈도 넉넉해서 전에 구매해서 너무 좋아서 재구매했어요
# 11707                     14242 근데 면이 쫀쫀한 편이라 한여름에 더울 수도
# 11714                                  자주 입어 물 빠져서 또 샀어요
# 11718  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...
#
# [5794 rows x 1 columns]

# %%
product_review.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/product_leggings.csv', encoding='utf-8-sig')

# %%
product_review['review_type'] = 'product'
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_24708\1388604072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   product_review['review_type'] = 'product'

# %%
all_review = pd.concat([service_review, product_review], axis = 0)
all_review
# Out:
#                              add_rule_based_split_review review_type
# 0                                              저렴하고 괜찮네요     service
# 9                                         가격 대비 완전히 만족해요     service
# 11      운동할 때 입어 여고 2벌 구매했는데 2벌 정도 더 사서 입ㅇ이어야겠어요 편하고 좋아요     service
# 15                                            그냥 가격만큼이네요     service
# 18                                                배송 빠르고     service
# ...                                                  ...         ...
# 11702                               소재도 면이라서 부드럽고 너무 좋아요     product
# 11703                    사이즈도 넉넉해서 전에 구매해서 너무 좋아서 재구매했어요     product
# 11707                     14242 근데 면이 쫀쫀한 편이라 한여름에 더울 수도     product
# 11714                                  자주 입어 물 빠져서 또 샀어요     product
# 11718  조금 아소변운 점은 지난번 구매했던 것과 같은 사이즈인데 기장이 약 2센티 정도 좀...     product
#
# [7403 rows x 2 columns]

# %%
all_review.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/all_review_leggings.csv', encoding='utf-8-sig')

# %% [markdown]
# #### create dataset for fine-tuning

# %%
import pandas as pd

fine_data = pd.read_csv("C:/Users\shopperhouse/Code/GEN_Ailee/product_pos.csv", index_col = 0)
fine_data
# Out:
#                              add_rule_based_split_review  \
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬
# 19                                            작아서 휴대도 굿굿
# ...                                                  ...
# 18645                                       가볍고 휴대하기 좋아요
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...
# 18647                                        요 사이즈가 딱이네요
# 18649                                   켔써요 노란색이 너무 귀엽군요
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
#                Tokenized_sentence Tokenized_sentence_list Tokenized_morphs
# 3                          ['기능']                      기능               기능
# 4            ['콤팩트', '디자인', '실용']            콤팩트, 디자인, 실용       콤팩트 디자인 실용
# 8                  ['전면', '스크래치']                전면, 스크래치          전면 스크래치
# 15              ['멀티어댑터', '해외여행']             멀티어댑터, 해외여행       멀티어댑터 해외여행
# 19                         ['휴대']                      휴대               휴대
# ...                           ...                     ...              ...
# 18645                      ['휴대']                      휴대               휴대
# 18646  ['C타입', '충전', '변압기', '충전']        C타입, 충전, 변압기, 충전    C타입 충전 변압기 충전
# 18647                     ['사이즈']                     사이즈              사이즈
# 18649                     ['노란색']                     노란색              노란색
# 18652            ['손', '색', '여행']                손, 색, 여행           손 색 여행
#
# [8102 rows x 4 columns]

# %%
fine_data = fine_data.dropna()
fine_data.drop_duplicates(subset='add_rule_based_split_review', inplace = True)
# Out:
# C:\Users\shopperhouse\AppData\Local\Temp\ipykernel_10600\3670559001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fine_data.drop_duplicates(subset='add_rule_based_split_review', inplace = True)

# %%
len(fine_data)
# Out:
# 6776

# %%
sample_fine_data = fine_data.sample(frac = 0.2)

# %%
sample_fine_data.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/sample_finetuning_data.csv')
